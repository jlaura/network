# %%
from collections import defaultdict, OrderedDict
import math
import os

import pysal as ps
from pysal.weights.util import get_ids

import random

# %% [markdown]
# ##Class to represent the network

# %%
class Network:
    def __init__(self, in_shp):
        self.in_shp = in_shp

        self.adjacencylist = defaultdict(list)
        self.nodes = {}
        self.edge_lengths = {}
        self.edges = []
        
        self.extractnetwork()
        self.node_coords = dict((value, key) for key, value in self.nodes.iteritems())
        self.w = ps.weights.W(self.adjacencylist)
    
    def compute_length(self, v0, v1):
        """
        Compute the euclidean distance between two points.
        """
        return math.sqrt((v0[0] - v1[0])**2 + (v0[1] - v1[1])**2)
    
    def extractnetwork(self):
        """
        Using the same logic as the high efficiency areal unit weights creation
        extract the network from the edges / vertices.
        """
        nodecount = 0
        shps = ps.open(self.in_shp)
        for shp in shps:
            vertices = shp.vertices
            print vertices
            for i, v in enumerate(vertices[:-1]):
                try:
                    vid = self.nodes[v]
                except:
                    self.nodes[v] = vid = nodecount
                    nodecount += 1
                try:
                    nvid = self.nodes[vertices[i+1]]
                except:
                    self.nodes[vertices[i+1]] = nvid = nodecount
                    nodecount += 1

                self.adjacencylist[vid].append(nvid)
                self.adjacencylist[nvid].append(vid)

                edge = (vid, nvid)
                self.edges.append(edge)
                length = self.compute_length(v, vertices[i+1])
                self.edge_lengths[edge] = length
             
    def contiguityweights(self):
        """
        Create a contiguity based W object
        """
        self.wtype = 'Contiguity'
        self.w = ps.weights.W(self.adjacencylist)
        
    def distanceweights(self, threshold):
        """
        Create distance based weights
        """
        self.wtype='Distance: {}'.format(threshold)
        print self.edge_lengths
        
        self.w = ps.weights.W()

# %% [markdown]
# ##Class to represent a point pattern
#
# Question: We do not have a standard internal data representation.  I am adopting a pseudo geoJSON spec (the outer FeatureCollection is omitted).  What do we want to do?

# %%
class PointPattern():
    def __init__(self, shapefile, idvariable=None, attribute=False):
        self.points = {}
        
        #Get id variables if requested
        if idvariable:
            ids = get_ids(shapefile, idvariable)
        else:
            ids = None
        
        pts = ps.open(shapefile)
        
        #Get attributes if requested
        if attribute == True:
            dbname = os.path.splitext(shapefile)[0] + '.dbf'
            db = ps.open(dbname)
        else:
            db = None
            
        for i, pt in enumerate(pts):
            if ids and db:
                self.points[ids[i]] = {'coordinates':pt, 'properties':db[i]}       
            elif ids and not db:
                self.points[ids[i]] = {'coordinates':pt, 'properties':None}
            elif not ids and db:
                self.points[i] = {'coordinates':pt, 'properties':db[i]}
            else:
                self.points[i] = {'coordinates':pt, 'properties':None}
 
        pts.close()
        db.close()

# %% [markdown]
# ##Function to snap edges to points and points to edges
#
# This is a two parter: a class to subclass ordereddict so that it can be sorted and then a function that brute force computes the nearest edge to a point.

# %%
class SortedEdges(OrderedDict):
    def next_key(self, key):
        next = self._OrderedDict__map[key][1]
        if next is self._OrderedDict__root:
            raise ValueError("{!r} is the last key.".format(key))
        return next[2]
    def first_key(self):
        for key in self: return key
        raise ValueError("No sorted edges remain.")
        
def snap_to_edge(network, pointpattern):
    """
    Snap point observations to network edges.
    
    Parameters
    -----------
    network       obj PySAL Network Object
    pointpattern  obj PySAL Point Pattern Object
    
    Returns
    obs_to_edge   dict with edge as key and list of points as value
    edge_to_obs   dict with point id as key and edge tuple as value
    """
    obs_to_edge = {}
    for pt_index, point in pointpattern.points.iteritems():
        x0 = point['coordinates'][0]
        y0 = point['coordinates'][1]
        
        d = {}
        vectors = {}
        c = 0
        
        for edge in network.edges:
            xi = network.node_coords[edge[0]][0]
            yi = network.node_coords[edge[0]][1]
            xi1 = network.node_coords[edge[1]][0]
            yi1 = network.node_coords[edge[1]][1]
            
            num = ((yi1 - yi)*(x0-xi)-(xi1-xi)*(y0-yi))
            denom = ((yi1-yi)**2 + (xi1-xi)**2)
            k = num / denom
            distance = abs(num) / math.sqrt(((yi1-yi)**2 + (xi1-xi)**2))
            vectors[c] = (xi, xi1, yi, yi1,k,edge)
            d[distance] = c
            c += 1
            
        min_dist = SortedEdges(sorted(d.items()))
        for dist, vector_id in min_dist.iteritems():
            value = vectors[vector_id]
            xi = value[0]
            xi1 = value[1]
            yi = value[2]
            yi1 = value[3]
            k = value[4]
            edge = value[5]
            #Okabe Method
            x = x0 - k * (yi1 - yi)
            y = y0 + k * (xi1 - xi)
            if xi <= x <= xi1 or xi1 <= x <= xi and yi <= y <= yi1 or yi1 <=y <= yi:
                #print "{} intersections edge {} at {}".format(pt_index, edge, (x,y))
                if edge not in obs_to_edge.keys():
                    obs_to_edge[edge] = {pt_index: (x,y)}
                else:
                    obs_to_edge[edge][pt_index] =  (x,y)
                break
            else:
                #either pi or pi+1 are the nearest point on that edge.
                #If this point is closer than the next distance, we can break, the
                # observation intersects the node with the shorter
                # distance.
                pi = (xi, yi)
                pi1 = (xi1, yi1)
                p0 = (x0,y0)
                dist_pi = ps.cg.standalone.get_points_dist(p0, pi)
                dist_pi1 = ps.cg.standalone.get_points_dist(p0, pi1)
                if dist_pi < dist_pi1:
                    node_dist = dist_pi
                    (x,y) = pi
                else:
                    node_dist = dist_pi1
                    (x,y) = pi1
                if node_dist < min_dist.next_key(dist):
                    if edge not in obs_to_edge.keys():
                        obs_to_edge[edge] = {pt_index: (x,y)}
                    else:
                        obs_to_edge[edge][pt_index] =  (x,y)
                    break
    edge_to_obs = {}
            
    return obs_to_edge, edge_to_obs

# %%
def count_per_edge(obs_on_network):
    """
    Snaps observations to the nearest edge and then counts
        the number of observations per edge.

    Parameters
    ----------
    obs_on_network: dict of observations on the network
        {(edge): {pt_id: (coords)}} or {edge: [(coord), (coord), (coord)]}
    Returns
    -------
    counts: dict {(edge):count}
    """

    counts = {}
    for key in obs_on_network.iterkeys():
        counts[key] = len(obs_on_network[key])
    return counts

# %%
def threshold_distance(ntw, cost, node, threshold, midpoint=False):
    """
    Parameters
    ----------
    ntw         pysal network object
    cost        
    """
    def get_neighbor_distances(wed, v0, l):
        edges = wed.enum_links_node(v0)
        neighbors = {}
        for e in edges:
            if e[0] != v0:
                neighbors[e[0]] = l[e]
            else:
                neighbors[e[1]] = l[e]

        return neighbors

    near = []
    v0 = node
    distance = [float('inf') for x in wed.node_list]
    distance[wed.node_list.index(v0)] = 0
    pred = [None for x in wed.node_list]
    a = set()
    a.add(v0)
    while len(a) > 0:
        #Get node with the lowest value from distance
        dist = float('inf')
        for node in a:
            if distance[node] < dist:
                dist = distance[node]
                v = node
        #Remove that node from the set
        a.remove(v)
        last = v
        if distance[v] <= threshold:
            near.append(v)
        elif distance[v] > threshold:
            break
        #4. Get the neighbors to the current node
        neighbors = get_neighbor_distances(wed, v, cost)
        for v1, indiv_cost in neighbors.iteritems():
            if distance[v1] > distance[v] + indiv_cost:
                distance[v1] = distance[v] + indiv_cost
                pred[v1] = v
                a.add(v1)
    return near,pred

# %% [markdown]
# ##Testing

# %%
import networkx as nx
# %pylab osx
ntw = Network('geodanet/streets.shp')
pts = PointPattern('geodanet/crimes.shp', attribute=True)
obs_to_edge, edge_to_obs = snap_to_edge(ntw, pts)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x108e91110>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91410>
# <pysal.cg.shapes.Chain object at 0x10d0c4610>
# <pysal.cg.shapes.Chain object at 0x108e91390>

# %%
print len(ntw.edges)
# Out:
# 303

# %%
ps.esda.moran.Moran(y, ntw.w, permutations=999)
# Out:
# 287
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-9a0726319fc7> in <module>()
#       9 y = np.array(y)
#      10 print len(y)
# ---> 11 ps.esda.moran.Moran(y, ntw.w, permutations=999)
#
# /Users/Jay/github/pysal/pysal/esda/moran.pyc in __init__(self, y, w, transformation, permutations, two_tailed)
#     132         self.permutations = permutations
#     133         self.__moments()
# --> 134         self.I = self.__calc(self.z)
#     135         self.z_norm = (self.I - self.EI) / self.seI_norm
#     136         self.z_rand = (self.I - self.EI) / self.seI_rand
#
# /Users/Jay/github/pysal/pysal/esda/moran.pyc in __calc(self, z)
#     193
#     194     def __calc(self, z):
# --> 195         zl = slag(self.w, z)
#     196         inum = sum(z * zl)
#     197         return self.n / self.w.s0 * inum / self.z2ss
#
# /Users/Jay/github/pysal/pysal/weights/spatial_lag.pyc in lag_spatial(w, y)
#      82
#      83     """
# ---> 84     return w.sparse * y
#
# /Users/jay/anaconda/lib/python2.7/site-packages/scipy/sparse/base.pyc in __mul__(self, other)
#     325             # dense row or column vector
#     326             if other.shape != (N,) and other.shape != (N,1):
# --> 327                 raise ValueError('dimension mismatch')
#     328
#     329             result = self._mul_vector(np.ravel(other))
#
# ValueError: dimension mismatch

# %% [markdown]
# ##Visual validation of the geodanet example: network extraction

# %%
g = nx.Graph()
for e in ntw.edges:
    g.add_edge(*e)
for n, p in ntw.node_coords.iteritems():
    g.node[n] = p
nx.draw(g, ntw.node_coords, node_size=30)

# %% [markdown]
# ##Visual validation of the geodanet example: point pattern

# %%
for k,point in pts.points.iteritems():
    plot(point['coordinates'][0], point['coordinates'][1], 'bo')


g = nx.Graph()
for e in ntw.edges:
    g.add_edge(*e)
for n, p in ntw.node_coords.iteritems():
    g.node[n] = p
nx.draw(g, ntw.node_coords, node_size=30)

# %% [markdown]
# ## Visual validation of observations snapped to edges

# %%
for k,point in pts.points.iteritems():
    plot(point['coordinates'][0], point['coordinates'][1], 'bo')

for v in obs_to_edge.itervalues():
    for k, obs in v.iteritems():
        plot(obs[0], obs[1], 'b*')

g = nx.Graph()
for e in ntw.edges:
    try:
        weight = len(obs_to_edge[e])
    except:
        weight = 0
    g.add_edge(*e, weight=weight)
for n, p in ntw.node_coords.iteritems():
    g.node[n] = p
nx.draw(g, ntw.node_coords, node_size=30)

# %% [markdown]
# ## Visual validation of counts per edge.

# %%
for k,point in pts.points.iteritems():
    plot(point['coordinates'][0], point['coordinates'][1], 'bo')

g = nx.Graph()
for e in ntw.edges:
    try:
        weight = len(obs_to_edge[e])
    except:
        weight = 0
    g.add_edge(*e, weight=weight)
for n, p in ntw.node_coords.iteritems():
    g.node[n] = p

edge_labels=dict([((u,v,),d['weight'])
             for u,v,d in g.edges(data=True)])
nx.draw(g, ntw.node_coords, node_size=30)
nx.draw_networkx_edge_labels(g,ntw.node_coords,edge_labels=edge_labels)
show()

# %% [markdown]
# #ESDA
# To run Moran's or Local Moran's we require a vector of attributes (counts in this case), and a W object.

# %%
print ntw.w.neighbors
print obs_to_edge
# Out:
# defaultdict(<type 'list'>, {0: [1, 2], 1: [0, 110, 127, 213], 2: [0, 117, 118, 170], 3: [4, 23, 10], 4: [3, 176, 166], 5: [6, 9], 6: [5, 7, 72], 7: [8, 6, 206], 8: [7, 9], 9: [8, 5], 10: [11, 3, 55, 166], 11: [10, 12, 68], 12: [11, 13, 179, 201], 13: [14, 12], 14: [13, 15, 139, 203], 15: [16, 14], 16: [15, 17, 138, 223], 17: [16, 25, 41], 18: [19, 21, 175], 19: [18, 20, 170], 20: [19, 22, 174, 228], 21: [18, 96, 114], 22: [23, 20], 23: [22, 3, 151, 176], 24: [25, 26, 48], 25: [24, 17], 26: [24, 27], 27: [26, 28, 74], 28: [27, 29], 29: [28, 30], 30: [29, 31, 208], 31: [30, 32], 32: [31, 106], 33: [34, 153], 34: [33, 35], 35: [34, 36, 136], 36: [35, 37, 144], 37: [36, 38], 38: [37, 39], 39: [38, 40, 149], 40: [39, 41], 41: [40, 17], 42: [43, 44], 43: [42, 45, 201, 218], 44: [42, 65, 166, 167], 45: [46, 43], 46: [45, 47, 203, 221], 47: [48, 46], 48: [47, 24, 222, 223], 49: [50, 51], 50: [49, 154, 165], 51: [49, 52], 52: [51, 53, 131], 53: [52, 54], 54: [53, 55, 121, 66], 55: [54, 10, 150], 56: [57, 58], 57: [56, 69, 70], 58: [56, 169, 204], 59: [60, 94, 96], 60: [59, 61, 175, 214], 61: [60, 62, 209], 62: [61, 63, 174, 211], 63: [62, 64, 216], 64: [63, 65, 176, 188], 65: [44, 64], 66: [67, 68, 54, 145], 67: [66], 68: [66, 11], 69: [57, 81, 167, 168], 70: [57, 71, 218, 219], 71: [72, 70], 72: [71, 73, 6, 221], 73: [72, 74, 220], 74: [73, 27, 222, 224], 75: [76, 95, 97], 76: [75, 77, 214, 215], 77: [76, 78, 209, 210], 78: [77, 79, 211, 212], 79: [78, 80, 216, 217], 80: [79, 81, 180, 188], 81: [69, 80], 82: [83, 88], 83: [82, 84, 192], 84: [83, 89], 85: [86, 98], 86: [85, 87, 189], 87: [88, 86], 88: [87, 82, 191], 89: [84, 90, 182], 90: [89, 91], 91: [90, 92], 92: [91, 99, 169], 93: [94, 95], 94: [93, 59], 95: [93, 75], 96: [21, 59], 97: [75, 98], 98: [97, 85], 99: [92, 100], 100: [99, 101, 204], 101: [100, 102], 102: [101, 103], 103: [102, 104, 206], 104: [103, 105], 105: [104, 106], 106: [105, 32, 208], 107: [108, 109], 108: [107, 160], 109: [107, 110], 110: [109, 111, 1], 111: [110, 112], 112: [111, 113], 113: [112, 114, 118], 114: [113, 21], 115: [116, 117], 116: [115, 119, 226, 228], 117: [2, 115], 118: [113, 2], 119: [116, 120, 229], 120: [119, 121, 172, 151], 121: [54, 120], 122: [123, 124], 123: [122, 125, 162, 227], 124: [122, 160, 213], 125: [126, 123], 126: [125, 164, 171], 127: [128, 1], 128: [127, 129, 225, 227], 129: [128, 130, 229], 130: [129, 131, 171, 172], 131: [52, 130], 132: [133, 134], 133: [132, 196], 134: [132, 177, 142], 135: [136, 194, 143], 136: [135, 35, 198, 144], 137: [138, 139], 138: [137, 149, 16], 139: [137, 147, 14], 140: [141, 142], 141: [140, 143, 196, 197], 142: [140, 134, 178], 143: [141, 144, 135, 195], 144: [143, 36, 136, 199], 145: [66, 146, 178, 179], 146: [147, 145], 147: [146, 148, 197, 139], 148: [147, 149, 195], 149: [148, 39, 199, 138], 150: [55, 152], 151: [152, 120, 23], 152: [151, 150], 153: [33, 159], 154: [50, 155], 155: [154, 156], 156: [155, 157, 177], 157: [156, 158], 158: [157, 159], 159: [158, 153], 160: [108, 161, 124], 161: [160, 162], 162: [161, 163, 123], 163: [162, 164], 164: [163, 165, 126], 165: [164, 50], 166: [10, 44, 4, 200], 167: [44, 69], 168: [69, 169], 169: [168, 92, 193, 58], 170: [19, 2], 171: [126, 130], 172: [130, 120], 173: [174, 175], 174: [173, 62, 20], 175: [173, 18, 60], 176: [4, 23, 64], 177: [156, 134], 178: [142, 145], 179: [145, 12], 180: [80, 181], 181: [180, 187], 182: [183, 89, 193], 183: [182, 184], 184: [183, 185], 185: [184, 186], 186: [185, 187], 187: [186, 181], 188: [64, 80], 189: [190, 215, 86], 190: [189, 191, 210], 191: [190, 192, 212, 88], 192: [191, 83, 217], 193: [169, 182], 194: [135], 195: [143, 148], 196: [133, 141], 197: [141, 147], 198: [136], 199: [144, 149], 200: [201, 166], 201: [200, 202, 12, 43], 202: [203, 201], 203: [202, 14, 46], 204: [58, 205, 219, 100], 205: [206, 204], 206: [205, 207, 7, 103], 207: [206, 208, 220], 208: [207, 30, 224, 106], 209: [61, 77], 210: [77, 190], 211: [62, 78], 212: [78, 191], 213: [124, 1], 214:  ...
# {(86, 87): {283: (727804.0040578609, 881243.4056562684)}, (204, 219): {258: (725224.7371647599, 880685.2430892603)}, (156, 157): {20: (725112.2575824127, 875974.7332731001)}, (40, 41): {96: (723447.2843278534, 878011.4583735463), 97: (723447.2843278534, 878011.4583735463), 98: (723448.3670241258, 878087.5073009136), 99: (723448.3670241258, 878087.5073009136), 100: (723448.3670241258, 878087.5073009136), 101: (723448.3670241258, 878087.5073009136), 102: (723448.3670241258, 878087.5073009136), 111: (723450.2436689772, 878219.3234266726)}, (162, 163): {2: (727393.1393952939, 875955.7896800487), 4: (727526.93574214, 875953.0049328394)}, (32, 31): {281: (723414.4119225407, 881215.2038743038), 282: (723414.3791485544, 881216.2346283447)}, (160, 161): {17: (728195.403349951, 875937.2495400191), 3: (728018.2294436245, 875939.908900934)}, (183, 184): {264: (726901.5389345714, 880725.2123567868), 262: (726901.5389345714, 880725.2123567868), 263: (726901.5389345714, 880725.2123567868)}, (11, 12): {154: (725548.0161838992, 878621.8054939024)}, (36, 37): {60: (723439.607723568, 877182.2585050084), 61: (723439.6240112177, 877183.2742785653)}, (72, 221): {197: (724430.8817920856, 879756.0791892534), 198: (724430.8817920856, 879756.0791892534), 199: (724430.8817920856, 879756.0791892534), 200: (724430.8817920856, 879756.0791892534), 201: (724430.8817920856, 879756.0791892534), 202: (724430.8817920856, 879756.0791892534), 203: (724430.8817920856, 879756.0791892534), 204: (724430.8817920856, 879756.0791892534), 205: (724430.8817920856, 879756.0791892534), 206: (724430.8817920856, 879756.0791892534), 207: (724430.8817920856, 879756.0791892534), 208: (724430.8817920856, 879756.0791892534), 209: (724430.8817920856, 879756.0791892534), 210: (724430.8817920856, 879756.0791892534), 211: (724430.8817920856, 879756.0791892534), 212: (724430.8817920856, 879756.0791892534), 213: (724430.8817920856, 879756.0791892534), 214: (724430.8817920856, 879756.0791892534), 215: (724430.8817920856, 879756.0791892534), 216: (724430.8817920856, 879756.0791892534), 217: (724430.8817920856, 879756.0791892534), 218: (724430.8817920856, 879756.0791892534), 219: (724430.8817920856, 879756.0791892534), 220: (724430.8817920856, 879756.0791892534), 221: (724430.8817920856, 879756.0791892534), 222: (724430.8817920856, 879756.0791892534), 223: (724430.8817920856, 879756.0791892534), 224: (724430.8817920856, 879756.0791892534), 225: (724430.881792678, 879756.0784195428), 226: (724430.881792678, 879756.0784195428), 227: (724430.881792678, 879756.0784195428), 228: (724430.881792678, 879756.0784195428), 229: (724430.881792678, 879756.0784195428), 230: (724430.881792678, 879756.0784195428), 231: (724430.881792678, 879756.0784195428), 232: (724430.881792678, 879756.0784195428), 233: (724430.881792678, 879756.0784195428)}, (155, 156): {6: (725271.9136852906, 875972.7771959687)}, (117, 115): {76: (728090.8213661326, 877785.6493319117), 77: (728032.8459713327, 877785.5984779804), 79: (728060.8731418536, 877785.6230624064), 80: (728020.9056276699, 877785.5880043403), 81: (728079.9055822743, 877785.6397569786), 83: (727779.9137075708, 877785.376614895)}, (128, 129): {54: (727375.0229503858, 877022.4005687127)}, (158, 159): {11: (724327.4968262629, 875985.2475279295)}, (37, 38): {72: (723441.5677280007, 877437.0772090938), 68: (723441.571420366, 877432.0764734497), 69: (723441.5677280007, 877437.0772090938), 70: (723441.5677280007, 877437.0772090938), 71: (723441.5677280007, 877437.0772090938)}, (57, 70): {241: (725447.6117220746, 880196.3665744092)}, (226, 225): {73: (727576.8344686192, 877446.9329728821), 78: (727576.6729463865, 877632.8867959977)}, (69, 57): {236: (725717.5903003681, 880192.7048515189)}, (14, 15): {160: (723884.0351967905, 878620.5117160691), 161: (723884.0351967905, 878620.5117160691), 162: (723884.0351967905, 878620.5117160691), 163: (723884.0351967905, 878620.5117160691), 143: (723788.9042711288, 878620.4396914039), 157: (724316.0190498352, 878620.8387757733), 158: ( ...
